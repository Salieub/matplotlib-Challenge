# %% [markdown]
# ## Observations and Insights

# %% [markdown]
# 1. At 0.84, there is a strong correlation between the weight of mice and the tumor volume for the capomulin regimen
# 2. The box plot showed that capomulin had the sloweest spread
# 3. There is consistency in the data as there was only one outlier with infubinol.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st
import numpy as np
from scipy.stats import sem
from scipy.stats import linregress

# Study data files
mouse_metadata_path = "data/Mouse_metadata.csv"
study_results_path = "data/Study_results.csv"

# Read the mouse data and the study results
mouse_metadata = pd.read_csv(mouse_metadata_path)
study_results = pd.read_csv(study_results_path)

# Combine the data into a single dataset
combine_data=pd.merge(mouse_metadata,study_results, how ='inner',on='Mouse ID')


# Display the data table for preview
mouse_metadata.head()
study_results.head()
combine_data.head()
# Out:
#   Mouse ID Drug Regimen   Sex  Age_months  Weight (g)  Timepoint  \
# 0     k403     Ramicane  Male          21          16          0
# 1     k403     Ramicane  Male          21          16          5
# 2     k403     Ramicane  Male          21          16         10
# 3     k403     Ramicane  Male          21          16         15
# 4     k403     Ramicane  Male          21          16         20
#
#    Tumor Volume (mm3)  Metastatic Sites
# 0           45.000000                 0
# 1           38.825898                 0
# 2           35.014271                 1
# 3           34.223992                 1
# 4           32.997729                 1

# %%
# Checking the number of mice.
unique_id=combine_data["Mouse ID"].unique()
len(unique_id)
# Out:
# 249

# %%
# Getting the duplicate mice by ID number that shows up for Mouse ID and Timepoint. 

Mouse_ID_Timepoint=duplicates[['Mouse ID','Timepoint']]

Mouse_ID_Timepoint
# Out:
#      Mouse ID  Timepoint
# 0        k403          0
# 1        k403          5
# 2        k403         10
# 3        k403         15
# 4        k403         20
# ...       ...        ...
# 1888     z969         25
# 1889     z969         30
# 1890     z969         35
# 1891     z969         40
# 1892     z969         45
#
# [1881 rows x 2 columns]

# %%
# Optional: Get all the data for the duplicate mouse ID. 

duplicates=combine_data[combine_data['Mouse ID'].duplicated(keep=False)]

duplicates
# Out:
#      Mouse ID Drug Regimen   Sex  Age_months  Weight (g)  Timepoint  \
# 0        k403     Ramicane  Male          21          16          0
# 1        k403     Ramicane  Male          21          16          5
# 2        k403     Ramicane  Male          21          16         10
# 3        k403     Ramicane  Male          21          16         15
# 4        k403     Ramicane  Male          21          16         20
# ...       ...          ...   ...         ...         ...        ...
# 1888     z969     Naftisol  Male           9          30         25
# 1889     z969     Naftisol  Male           9          30         30
# 1890     z969     Naftisol  Male           9          30         35
# 1891     z969     Naftisol  Male           9          30         40
# 1892     z969     Naftisol  Male           9          30         45
#
#       Tumor Volume (mm3)  Metastatic Sites
# 0              45.000000                 0
# 1              38.825898                 0
# ...

# %%
# Create a clean DataFrame by dropping the duplicate mouse by its ID.
combine_data.drop_duplicates("Mouse ID")
# Out:
#      Mouse ID Drug Regimen     Sex  Age_months  Weight (g)  Timepoint  \
# 0        k403     Ramicane    Male          21          16          0
# 10       s185    Capomulin  Female           3          17          0
# 20       x401    Capomulin  Female          16          15          0
# 30       m601    Capomulin    Male          22          17          0
# 40       g791     Ramicane    Male          11          16          0
# ...       ...          ...     ...         ...         ...        ...
# 1858     z314     Stelasyn  Female          21          28          0
# 1860     z435     Propriva  Female          12          26          0
# 1863     z581    Infubinol  Female          24          25          0
# 1873     z795     Naftisol  Female          13          29          0
# 1883     z969     Naftisol    Male           9          30          0
#
#       Tumor Volume (mm3)  Metastatic Sites
# 0                   45.0                 0
# ...

# %%
# Checking the number of mice in the clean DataFrame.
combine_data.drop_duplicates("Mouse ID")
# Out:
#      Mouse ID Drug Regimen     Sex  Age_months  Weight (g)  Timepoint  \
# 0        k403     Ramicane    Male          21          16          0
# 10       s185    Capomulin  Female           3          17          0
# 20       x401    Capomulin  Female          16          15          0
# 30       m601    Capomulin    Male          22          17          0
# 40       g791     Ramicane    Male          11          16          0
# ...       ...          ...     ...         ...         ...        ...
# 1858     z314     Stelasyn  Female          21          28          0
# 1860     z435     Propriva  Female          12          26          0
# 1863     z581    Infubinol  Female          24          25          0
# 1873     z795     Naftisol  Female          13          29          0
# 1883     z969     Naftisol    Male           9          30          0
#
#       Tumor Volume (mm3)  Metastatic Sites
# 0                   45.0                 0
# ...

# %% [markdown]
# ## Summary Statistics

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, and SEM of the tumor volume for each regimen

# Use groupby and summary statistical methods to calculate the following properties of each drug regimen: 
drug_regimen = combine_data.groupby('Drug Regimen')

# mean, median, variance, standard deviation, and SEM of the tumor volume.

tumor_mean = drug_regimen['Tumor Volume (mm3)'].mean()
tumor_median = drug_regimen['Tumor Volume (mm3)'].median()
tumor_variance= drug_regimen['Tumor Volume (mm3)'].var()
tumor_stdev = drug_regimen['Tumor Volume (mm3)'].std()
tumor_sem = drug_regimen['Tumor Volume (mm3)'].sem()

# Assemble the resulting series into a single summary dataframe.
summary_drug_statistics = pd.DataFrame({'Mean': tumor_mean, 'Median': tumor_median, 'Variance': tumor_variance,
                                   'Standard Deviation': tumor_stdev, 'SEM': tumor_sem})

summary_drug_statistics.head()
# Out:
#                    Mean     Median   Variance  Standard Deviation       SEM
# Drug Regimen
# Capomulin     40.675741  41.557809  24.947764            4.994774  0.329346
# Ceftamin      52.591172  51.776157  39.290177            6.268188  0.469821
# Infubinol     52.884795  51.820584  43.128684            6.567243  0.492236
# Ketapril      55.235638  53.698743  68.553577            8.279709  0.603860
# Naftisol      54.331565  52.509285  66.173479            8.134708  0.596466

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, and SEM of the tumor volume for each regimen

# Using the aggregation method, produce the same summary statistics in a single line

summary_drug_statistics2= combine_data.groupby(['Drug Regimen'])['Tumor Volume (mm3)'].agg(['mean', 'median', 'var', 'std', 'sem'])

summary_drug_statistics2.head()
# Out:
#                    mean     median        var       std       sem
# Drug Regimen
# Capomulin     40.675741  41.557809  24.947764  4.994774  0.329346
# Ceftamin      52.591172  51.776157  39.290177  6.268188  0.469821
# Infubinol     52.884795  51.820584  43.128684  6.567243  0.492236
# Ketapril      55.235638  53.698743  68.553577  8.279709  0.603860
# Naftisol      54.331565  52.509285  66.173479  8.134708  0.596466

# %% [markdown]
# ## Bar and Pie Charts

# %%
# Generate a bar plot showing the total number of timepoints for all mice tested for each drug regimen using Pandas.

bar_plot = combine_data['Drug Regimen'].value_counts().plot.bar(width=0.8)

# labels for axes
bar_plot.set_xlabel("Drug Regimen")
bar_plot.set_ylabel("Number of Time Points")
bar_plot.set_title("Number of Time Points for Each Treatment Regimen")
# Out:
# Text(0.5, 1.0, 'Number of Time Points for Each Treatment Regimen')

# %%
# Generate a bar plot showing the total number of timepoints for all mice tested for each drug regimen using pyplot.

#calculating regimen time points
regimen_timepoints = combine_data['Drug Regimen'].value_counts()

# The x_axis is set to the length of the regimen timepoints
x_axis = np.arange(len(regimen_timepoints))

plt.bar(x_axis, regimen_timepoints, width = 0.8)

tick_locations = [value for value in x_axis]
plt.xticks(tick_locations, regimen_timepoints.index.values)
plt.xticks(rotation=90)

# labels for axes
plt.xlabel("Drug Regimen")
plt.ylabel("Number of Time Points")
plt.title('Number of Time Points Points for Each Treatment Regimen')

plt.show()

# %%
# Generate a pie plot showing the distribution of female versus male mice using Pandas

# Count by Sex
sex_data= combine_data['Sex'].value_counts()

pie_plot = sex_data.plot.pie(autopct="%1.2f%%", startangle=90, title='Distribution of female vs male')

plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# Generate a pie plot showing the distribution of female versus male mice using pyplot

plt.pie(sex_data, labels=sex_data.index.values, autopct="%1.2f%%", startangle=90)
plt.title('Distribution of female vs male')


plt.show()

# %% [markdown]
# ## Quartiles, Outliers and Boxplots

# %%
# Calculate the final tumor volume of each mouse across four of the treatment regimens:  
# Capomulin, Ramicane, Infubinol, and Ceftamin

# Start by getting the last (greatest) timepoint for each mouse
max_timepoint= pd.DataFrame(combine_data.groupby('Mouse ID')['Timepoint'].max().sort_values()).reset_index().rename(columns={'Timepoint': 'max_timepoint'})
max_timepoint

# Merge this group df with the original dataframe to get the tumor volume at the last timepoint
consolidated_data = pd.merge(combine_data, max_timepoint, on='Mouse ID')
consolidated_data
# Out:
#      Mouse ID Drug Regimen   Sex  Age_months  Weight (g)  Timepoint  \
# 0        k403     Ramicane  Male          21          16          0
# 1        k403     Ramicane  Male          21          16          5
# 2        k403     Ramicane  Male          21          16         10
# 3        k403     Ramicane  Male          21          16         15
# 4        k403     Ramicane  Male          21          16         20
# ...       ...          ...   ...         ...         ...        ...
# 1888     z969     Naftisol  Male           9          30         25
# 1889     z969     Naftisol  Male           9          30         30
# 1890     z969     Naftisol  Male           9          30         35
# 1891     z969     Naftisol  Male           9          30         40
# 1892     z969     Naftisol  Male           9          30         45
#
#       Tumor Volume (mm3)  Metastatic Sites  max_timepoint
# 0              45.000000                 0             45
# ...

# %%
# Put treatments into a list for for loop (and later for plot labels)

treatments = ['Capomulin', 'Ceftamin', 'Infubinol', 'Keptapril','Naftsisol']

# Create empty list to fill with tumor vol data (for plotting)
Tumor_values = []

# Calculate the IQR and quantitatively determine if there are any potential outliers. 


    # Locate the rows which contain mice on each drug and get the tumor volumes
for treatment in treatments:
    
    treatment_data = consolidated_data.loc[consolidated_data['Drug Regimen'] == treatment]
    
    final_treatment = treatment_data.loc[treatment_data['Timepoint'] == treatment_data['max_timepoint']]
    
    # add subset 
    Tumor_volume = final_treatment['Tumor Volume (mm3)']
    Tumor_values.append(Tumor_volume)
    
    # Determine outliers using upper and lower bounds
    
    quartiles = Tumor_volume.quantile([.25,.5,.75])
    lowerq = quartiles[0.25]
    upperq = quartiles[0.75]
    iqr = upperq-lowerq
    print(f'IQR for {treatment}: {iqr}')
    
    lower_bound = lowerq - (1.5*iqr)
    upper_bound = upperq + (1.5*iqr)
    print(f'Lower Bound for {treatment}: {lower_bound}')
    print(f'Upper Bound for {treatment}: {upper_bound}')
    
    #checking for outliers
    outliers_count = (Tumor_volume.loc[(treatment_data['Tumor Volume (mm3)'] >= upper_bound) | 
                                        (treatment_data['Tumor Volume (mm3)'] <= lower_bound)]).count()
    print(f'Number of {treatment} outliers: {outliers_count}')
# Out:
# IQR for Capomulin: 7.781863460000004
# Lower Bound for Capomulin: 20.70456164999999
# Upper Bound for Capomulin: 51.83201549
# Number of Capomulin outliers: 0
# IQR for Ceftamin: 15.577752179999997
# Lower Bound for Ceftamin: 25.355449580000002
# Upper Bound for Ceftamin: 87.66645829999999
# Number of Ceftamin outliers: 0
# IQR for Infubinol: 11.477135160000003
# Lower Bound for Infubinol: 36.83290494999999
# Upper Bound for Infubinol: 82.74144559000001
# Number of Infubinol outliers: 1
# IQR for Keptapril: nan
# Lower Bound for Keptapril: nan
# Upper Bound for Keptapril: nan
# Number of Keptapril outliers: 0
# IQR for Naftsisol: nan
# Lower Bound for Naftsisol: nan
# Upper Bound for Naftsisol: nan
# Number of Naftsisol outliers: 0

# %%
# Generate a box plot of the final tumor volume of each mouse across four regimens of interest

flierprops = dict(marker='+', markerfacecolor='g', markersize=8, markeredgecolor='black')

plt.boxplot(Tumor_values, flierprops=flierprops)

#add labels
plt.title('Final Tumor Volume by Treatment')
plt.ylabel('Final Tumor Volume (mm3)')
plt.xticks([1, 2, 3, 4], ['Capomulin', 'Ramicane', 'Infubinol', 'Ceftamin'])

plt.show()

# %% [markdown]
# ## Line and Scatter Plots

# %%
# Generate a line plot of tumor volume vs. time point for a mouse treated with Capomulin

specific_mouse = combine_data.loc[combine_data['Mouse ID'] == 'x401']

plt.plot(specific_mouse['Tumor Volume (mm3)'], specific_mouse['Timepoint'], marker = '+',color ='r')

#labels
plt.xlabel("Tumor Volume(mm3)")
plt.ylabel("TimePoint")
plt.title("Capomulin Treatment of Mouse x401")

# show plot
plt.show()

# %%
# Generate a scatter plot of average tumor volume vs. mouse weight for the Capomulin regimen

#cases of capomulin regimen

capomulin_data= combine_data.loc[combine_data['Drug Regimen'] == 'Capomulin']

#average tumor volume

avg_vol= pd.DataFrame(capomulin_data.groupby('Mouse ID')['Tumor Volume (mm3)'].mean().sort_values()).reset_index().rename(columns={'Tumor Volume (mm3)': 'avg_tumor_vol'})

#merge the dataframes

avg_vol= pd.merge(capomulin_data, avg_vol, on='Mouse ID')

final_avg_vol= avg_vol[['Weight (g)', 'avg_tumor_vol']].drop_duplicates()
final_avg_vol

#axes
x = final_avg_vol['Weight (g)']
y = final_avg_vol['avg_tumor_vol']

# Create a scatter plot 
plt.scatter(x, y, marker='+',color='g')

# labels and title
plt.xlabel("Weight (g)")
plt.ylabel("Average Tumor Volume (mm3)")
plt.title('Average Tumor Volume by Weight')


# show plot
plt.show()

# %% [markdown]
# ## Correlation and Regression

# %%
# Calculate the correlation coefficient and linear regression model 
# for mouse weight and average tumor volume for the Capomulin regimen

#codes for capomulin from scatter plot

capomulin_data= combine_data.loc[combine_data['Drug Regimen'] == 'Capomulin']

avg_vol= pd.DataFrame(capomulin_data.groupby('Mouse ID')['Tumor Volume (mm3)'].mean().sort_values()).reset_index().rename(columns={'Tumor Volume (mm3)': 'avg_tumor_vol'})

avg_vol= pd.merge(capomulin_data, avg_vol, on='Mouse ID')

final_avg_vol= avg_vol[['Weight (g)', 'avg_tumor_vol']].drop_duplicates()
final_avg_vol

x = final_avg_vol['Weight (g)']
y = final_avg_vol['avg_tumor_vol']


# Correlation coefficient between mouse weight and average tumor volume
correlation = st.pearsonr(x,y)

print(f"""The correlation between weight and average tumor volume
on the Capomulin regimen is {round(correlation[0],2)}.""")

#linear regression

(slope, intercept, rvalue, pvalue, stderr) = linregress(x, y)
regress_values = x * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Plot linear regression on top of scatter plot
plt.scatter(x,y,marker="+",color="g")
plt.plot(x,regress_values,"r-")

# Annotate linear regression
plt.annotate(line_eq,(20,37),fontsize=18,color="b")

# Add labels and title to plot
plt.xlabel("Weight (g)")
plt.ylabel("Average Tumor Volume (mm3)")
plt.title('Average Tumor Volume by Weight')
plt.show()
# Out:
# The correlation between weight and average tumor volume
# on the Capomulin regimen is 0.84.
